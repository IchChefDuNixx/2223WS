# %% [markdown]
# # Text Classification

# %% [markdown]
# # Naive Bayes Classifier
#
# <div class="alert alert-success">
# Implement your own naive bayes classifier and apply it to the 20newsgroups dataset.
# </div>
# <ul>
#     <li>Load the '20newsgroups' dataset</li>
#     <li>Read the files and tokenize the text to obtain a "bag of words"</li>
#     <li>Implement the naive bayes classifier (pseudocode is given below)</li>
#     <li>Evaluate your classfier on the training/test set. Which accuracy can you achieve?</li>
# </ul>

# %% [markdown]
# ## Model
#
# As the name suggests, in the Naive Bayes Classifier (NB) we make use of Bayes' theorem to build a classifier. We are going to use the NB to map text documents to class labels $c \in \mathcal{C} = \{1, 2, \dots, M\}$. Each text document is represented as a "bag of words" - a feature vector $\mathbf{x} = (x_1, \dots, x_p)$ that has as many entries as there are words in our vocabulary $\mathcal{V}$, p = $|\mathcal{V}|$. Each dimension $i$ in $\mathbf{x}$ is associated with one word in the vocabulary. A value $x_i = 1$ if the word associated with dimension $i$ occurs in the document, and $x_i = 0$ if the word does not occur in the document.
#
# Before we can define the probabilistic model, we define the following random variables:
# - $X_1, \dots, X_p$: the $p$ binary indicator random variables associated with attributes/words
# - $C \in \{1, 2, \dots, M\}$: the random variable associated with the class of the document
#
# Given a dataset of text documents and class labels, our goal is to estimate:
#
# $$P[C | X_1, \dots, X_p]$$
#
# Then we can classify documents by simply finding the class $c$ that maximizes this conditional probability:
#
# $$h(\mathbf{x}) = \mathit{argmax}_{c \in \{1, 2, \dots, M\}} P[C=c | X_1=x_1, \dots, X_p=x_p]$$
#
# We can't estimate this quantity directly from our dataset...
#
# <div class="alert alert-warning">
# Why?
# </div>
#
# ..., but by using Bayes theorem we can write:
#
# $$P[C | X_1, \dots, X_p] = \frac{P[X_1, \dots, X_p | C] \cdot P[C]}{P[X_1, \dots, X_p]}$$
#
# That's already helpful. We can estimate $P[C]$ by calculating the relative frequencies of classes over all documents (regardless of their content). However, the joint distribution $P[X_1, \dots, X_p | C]$ is a little annoying. Even for tiny vocabulary sizes ($\approx 100$) we would have to store and estimate $2^{100}$-1 parameters.
# The Naive Bayes Classifier is called "Naive" because it makes one very strong assumption about the observation variables $X_1, \dots, X_p$: All $X_i$ are conditionally independent given the class $C$:
#
# $$P[X_1, \dots, X_p | C] \cdot P[C] =  P[C] \cdot  \prod_{i=1}^p P[X_i | C]$$
#
# <div class="alert alert-info">
# <b>Sanity Check:</b> Let's say we have documents from a newsgroup in which people discuss about politics. When we accept this independence assumption we acknowledge: Knowing that a document contains "Donald" does not alter our belief about whether this same document would also contain the word "Trump". $P[X_{'Trump'} = 1 | C = 2] = P[X_{'Trump'} = 1 | X_{'Donald'} = 1, C = 2]$. These independence assumptions will most likely be violated by any newsgroup. However, they lead to a very simple model and, in practice, the classifer yields very accurate predictions anyway.
# </div>
#
# Now the calculations are straight-forward. The terms $P[X_i | C]$ can be estimated by calculating the relative frequency of word $i$ per class $c$, resulting in a table of $p \cdot M$ conditional probabilities. And finally, we can make predictions by calculating:
#
# $$h(\mathbf{x}) = \mathit{argmax}_{c \in {1, 2, \dots, M}} P(C) \cdot \prod_{i=1}^p P(X_i | C)$$
#
#
#
#
#
#
# NOTE: We completely ignored the denominator $P[X_1, \dots, X_p]$ in the maximization.
#
# <div class="alert alert-warning">
# Why?
# </div>
#
# This ignorance is justified by the fact that the denominator is a function of the data and the data is fixed. Since the data is fixed, the denominator is a constant. As we are only interested in the class $c$ that maximizes the above quantity, the constant denominator is irrelevant. It would be a different story if we were interested in the class probabilities, then certainly would we have to take $P[X_1, \dots, X_p]$ into account. Otherwise $P[C | \cdot]$ wouldn't be a proper pmf.
#
# ### Classification rule
#
# The product of probabilities is numerically not stable. Therefore, we take the argmax of the **log** probabilities instead. Since **log** is a monotonic function, the result of argmax is not affected by this transformation.
#
# The final classification rule is then:
#
# $$h(\mathbf{x}) = \mathit{argmax}_{c \in {1, 2, \dots, M}} \log(P(C=c)) + \sum_{i=1}^p \log(P(X_i | C=c))$$

# %% [markdown]
# ### Graphical model representing the joint distribution over $C, X_1, X_2, \dots, X_p$
# <img src="nb-graph.png" height="200px" />

# %% [markdown]
# ## Data Set
# The 20 Newsgroups data set is a collection of approximately 20,000 newsgroup documents, partitioned (nearly) evenly across 20 different newsgroups. The data is organized into 20 different newsgroups, each corresponding to a different topic. Some of the newsgroups are very closely related to each other (e.g. comp.sys.ibm.pc.hardware / comp.sys.mac.hardware), while others are highly unrelated (e.g misc.forsale / soc.religion.christian). Here is a list of the 20 newsgroups, partitioned (more or less) according to subject matter:
#
#
#
#
# <table border=1>
# <tr>
# <td>comp.graphics<br>comp.os.ms-windows.misc<br>comp.sys.ibm.pc.hardware<br>comp.sys.mac.hardware<br>comp.windows.x</td>
# <td>rec.autos<br>rec.motorcycles<br>rec.sport.baseball<br>rec.sport.hockey</td>
# <td>sci.crypt<br>sci.electronics<br>sci.med<br>sci.space</td>
# </tr><tr>
# <td>misc.forsale</td>
# <td>talk.politics.misc<br>talk.politics.guns<br>talk.politics.mideast</td>
# <td>talk.religion.misc<br>alt.atheism<br>soc.religion.christian</td>
# </tr>
# </table>

# %% [markdown]
# ## Naive Bayes Pseudocode
# #### TrainMultinomialNB($\mathbb C$,$\mathbb D$)
# $V \leftarrow extractVocabulary(\mathbb D)$
# $N \leftarrow countDocs(\mathbb D)$
# for $c \in \mathbb C$:
# &nbsp;&nbsp;&nbsp;&nbsp;$N_c \leftarrow countDocsInClass(\mathbb D, c)$
# &nbsp;&nbsp;&nbsp;&nbsp;$prior[c] \leftarrow \frac{N_c}{N}$
# &nbsp;&nbsp;&nbsp;&nbsp;$text_c \leftarrow concatenateTextOfAllDocsInClass(\mathbb D, c)$
# &nbsp;&nbsp;&nbsp;&nbsp;for $t \in V$:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$T_{ct} \leftarrow countOccurrencesOfTerm(text_c,t)$
# &nbsp;&nbsp;&nbsp;&nbsp;for $t \in V$:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$condprob[c][t] \leftarrow \frac{T_{ct} + 1}{\sum_{t'}(T_{ct'} + 1)}$
# return $V,prior,condprob$
#
# #### ApplyMultinomialNB($\mathbb C,V,prior,condprob,d$)
# $W \leftarrow extractTermsFromDoc(V,d)$
# for $c \in \mathbb C$:
# &nbsp;&nbsp;&nbsp;&nbsp;$score[c] \leftarrow log(prior[c])$
# &nbsp;&nbsp;&nbsp;&nbsp;for $t \in W$:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$score[c] += log(condprob[c][t])$
# return $argmax_{c \in \mathbb C} score[c]$

# %% [markdown]
# ## Naive Bayes Helpers

# %%
# %matplotlib inline

import os
import pprint
import re
import codecs
import math

import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Simple file reading

# %%
with codecs.open('./newsgroups/20news-bydate-train/comp.graphics/37915', encoding='latin1') as file:
    pprint.pprint(file.readlines())
# Out:
# ['From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinckley)\n',
#  'Subject:   VOICE INPUT -- vendor information needed\n',
#  'Reply-To: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinckley)\n',
#  'Organization: University of Virginia\n',
#  'Lines: 27\n',
#  '\n',
#  '\n',
#  'Hello,\n',
#  '     I am looking to add voice input capability to a user interface I am\n',
#  'developing on an HP730 (UNIX) workstation.  I would greatly appreciate \n',
#  'information anyone would care to offer about voice input systems that are \n',
#  'easily accessible from the UNIX environment. \n',
#  '\n',
#  '     The names or adresses of applicable vendors, as well as any \n',
#  'experiences you have had with specific systems, would be very helpful.\n',
#  '\n',
#  '     Please respond via email; I will post a summary if there is \n',
#  'sufficient interest.\n',
#  '\n',
#  '\n',
#  'Thanks,\n',
#  'Ken\n',
#  '\n',
#  '\n',
#  "P.S.  I have found several impressive systems for IBM PC's, but I would \n",
#  'like to avoid the hassle of purchasing and maintaining a separate PC if \n',
#  'at all possible.\n',
#  '\n',
#  '-------------------------------------------------------------------------------\n',
#  'Ken Hinckley (kph2q@virginia.edu)\n',
#  'University of Virginia \n',
#  'Neurosurgical Visualization Laboratory\n',
#  '-------------------------------------------------------------------------------\n']

# %% [markdown]
# ### Tokenize strings

# %%
def tokenize_str(doc):
    """
    Splits a string ```doc``` into a sequence of tokens.
    Ignores tokens with #characters < 2
    """
    return re.findall(r'\b\w\w+\b', doc) 

def tokenize_file(doc_file):
    """
    Takes a file from the 20newsgroup dataset, 
    extracts the body of the message and tokenizes the body.
    Returns the list of tokens of the file.
    """
    with codecs.open(doc_file, encoding='latin1') as doc:
        doc = doc.read().lower()
        _header, _blankline, body = doc.partition('\n\n')
        return tokenize_str(body) # return all words with #characters > 1
    
pprint.pprint(tokenize_file('./newsgroups/20news-bydate-train/comp.graphics/37915')[:30])
# Out:
# ['hello',
#  'am',
#  'looking',
#  'to',
#  'add',
#  'voice',
#  'input',
#  'capability',
#  'to',
#  'user',
#  'interface',
#  'am',
#  'developing',
#  'on',
#  'an',
#  'hp730',
#  'unix',
#  'workstation',
#  'would',
#  'greatly',
#  'appreciate',
#  'information',
#  'anyone',
#  'would',
#  'care',
#  'to',
#  'offer',
#  'about',
#  'voice',
#  'input']

# %% [markdown]
# ### List content of directory

# %%
def getFileNames(path):
    """
    Given the name of a directory ```path```, 
    the function returns a sorted list of all files and directories found inside ```path```
    """
    return sorted([file_name for file_name in os.listdir(path)])

getFileNames("./newsgroups/20news-bydate-train/")
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# ## Naive Bayes Implementation

# %%
import os
import re
import math
import codecs
from sklearn import metrics


class NaiveBayesClassifier:
    def __init__(self, min_count=1):
        self.min_count = min_count
        self.vocabulary = {}
        self.num_docs = 0
        self.classes = {}
        self.priors = {}
        self.conditionals = {}

    def _build_vocab(self, path):
        """
        Reads through all files in the directory ```path``` and 
        builds a vocabulary of word counts from all files.
        
        The vocabulary is a dictionary and it contains words as keys 
        and the words' frequencies as values. An example is given below:
        {
            "a": 7483,
            "alfons": 23,
            ...
            "zulu": 2
        }
        
        This function also records a couple of statistics per class and stores
        this information in the dictionary ```classes```:
        - the number of documents: ```doc_counts```
        - the total number of terms encountered across all documents of the class: ```term_counts```
        - the local vocabulary of the class, built on the class' documents only: ```terms```
        
        The structure of ```classes``` is:
        {
            "nameOfClass1": {
                "doc_counts": 34,
                "term_counts": 38382,
                "terms": {
                    "a": 2,
                    "alfons": 398,
                    ...
                    "zulu": 1
                },
            "nameOfClass2": {
                "doc_counts": 2,
                "term_counts": 1099,
                "terms": {
                    "a": 1,
                    "alfons": 100,
                    ...
                    "zulu": 998
                },
            ...
        }
        In this example, the two documents in class 'nameOfClass2' only talk about 'zulu' and 'alfons'.
        
        The function also records the total number of all documents: ```num_docs```.
        """
        self.num_docs = 0
        for cn in os.listdir(path):
            if cn.startswith("."): #ignore hidden folders/files
                continue
            self.classes[cn] = {'doc_counts':0, 'term_counts':0, 'terms':{}}
            print(cn)
            cpath = os.path.join(path, cn)
            for dn in os.listdir(cpath):
                if dn.startswith("."):# ignore hidden folders/files
                    continue
                terms = tokenize_file(os.path.join(cpath, dn))
                
                self.num_docs += 1
                self.classes[cn]['doc_counts'] += 1
                
                # build vocabulary and count terms
                # builds a global vocabulary ```vocabulary``` over all classes
                # and one local vocabulary ```classes[cn]``` for each class ```cn```
                for term in terms:
                    self.classes[cn]['term_counts'] += 1
                    if not term in self.vocabulary:
                        self.vocabulary[term] = 1
                        self.classes[cn]['terms'][term] = 1
                    else:
                        self.vocabulary[term] += 1
                        if not term in self.classes[cn]['terms']:
                            self.classes[cn]['terms'][term] = 1
                        else:
                            self.classes[cn]['terms'][term] += 1
        
        # remove terms with frequency <= min_count
        self.vocabulary = {k:v for k,v in self.vocabulary.items() if v > self.min_count}
        
    def train_np(self, data_path):
        """
        Alternative implementation using numpy
        """
        self._build_vocab(data_path)
        
        P_C = np.zeros(len(self.classes))
        P_WgC = np.ones((len(self.classes), len(self.vocabulary)))
        
        cmap = {cn: i for i, cn in enumerate(self.classes)}
        tmap = {tn: i for i, tn in enumerate(self.vocabulary)}
        
        for cn in self.classes:
            P_C[cmap[cn]] = math.log(self.classes[cn]['doc_counts']) - math.log(self.num_docs)
            c_len = self.classes[cn]['term_counts']
            for tn in self.vocabulary:
                if tn in self.classes[cn]['terms']:
                    t_ct = self.classes[cn]['terms'][tn] if tn in self.classes[cn]['terms'] else 1
                    P_WgC[cmap[cn], tmap[tn]] = math.log(t_ct) - math.log(c_len + len(self.vocabulary))

    def train_py(self, data_path):
        """
        Estimates prior probabilites P(C) and conditional probabilities P(X_i | C)
        from text documents fround in ```data_path```.
        
        P(C) and P(X_i | C) are stored as log-probabilities log(P(C)) and log(P(X_i | C))
        in the respective dictionaries ```priors``` and ```conditionals```.
        
        ```priors``` is a dictionary with the following structure:
        {
            "nameOfClass1": P(C = 'nameOfClass1'),
            "nameOfClass2": P(C = 'nameOfClass2'),
            ...
        }
        
        ```conditionals``` is a dictionary. 
        Each key corresponds to the name of a class.
        The value at a particular key is an inner dictionary
        The inner dictionary contains all words from the global vocabulary
        and their respective log conditional probabilities P(X_i | C).
        The structure of is the following:
        {
            "nameOfClass1": {
                "a": -2.38,
                "alfons": -1.29,
                ...
                "zulu": -7.2
            },
            "nameOfClass2": {
                "a": -8.38,
                "alfons": -0.8,
                ...
                "zulu": -0.4
            },
            ...
        }
        
        The prior probabilities are estimated as:
        P(C=c) <- classes[c]['doc_counts'] / num_docs
        
        The conditional probabilities are estimated as:
        P(X_i = t | C = c) <- (classes[c][t] + 1) / (classes[c]['term_counts'] + len(vocabulary))
        """
        self._build_vocab(data_path)
        
        for cn in self.classes:
            # calculate priors
            self.priors[cn] = math.log(self.classes[cn]['doc_counts']) - math.log(self.num_docs)
            
            # calculate conditionals
            self.conditionals[cn] = {}
            cdict = self.classes[cn]['terms'] # dictionary of terms in cn
            c_len = self.classes[cn]['term_counts'] # sum(cdict.values()) # total number of terms in cn
            
            for term in self.vocabulary:
                t_ct = 1.  
                t_ct += cdict[term] if term in cdict else 0. # number of times seeing term t in cn 
                self.conditionals[cn][term] = math.log(t_ct) - math.log(c_len + len(self.vocabulary))

    def test(self, data_path):
        """
        Makes a prediction for each document found in the directory ```data_path```.
        Returns a list of true class labels and a list of predicted class labels.
        This function calls the actual prediction function ```_predict(doc_path)``` internally.
        """
        true_y = []
        pred_y = []

        for c in self.classes:
            print(c)
            for f in os.listdir(os.path.join(test_path, c)):
                if f.startswith("."): # ignore hidden folders/files
                    continue
                doc_path = os.path.join(test_path, c, f)
                _, predicted_class = self._predict(doc_path)
                pred_y.append(predicted_class)
                true_y.append(c)
        return true_y, pred_y
    """            
    def _predict(self, doc_path):

        For a given text document, given as path ```doc_path```,
        calculate the classification rule.
        
        As a reminder, the classification rule is: 
            argmax_c log(P(X_1 | C=c)) + ... + log(P(X_p | C=c)) + log(P(C=c))
        
        The required quantities have already been calculated during training. 
        They are stored in ```priors``` and ```conditionals```.

        
        token_list = tokenize_file(doc_path)

        scores = {}
        for c in self.classes:
            scores[c] = self.priors[c]
            for term in token_list:
                if term in self.vocabulary: # ignore unknown terms
                    scores[c] += self.conditionals[c][term]
        return scores, max(scores, key=scores.get)
    """
    def _predict(self, doc_path):
        W = tokenize_file(doc_path)
        scores = {}
        for c in self.classes:
            # calculate p(c|word1, word2, ..., wordn)
            # store it as scores[c] = p(c | word1, word2, ..., wordn)
            scores[c] = self.priors[c]
            for word in W:
                if word in self.vocabulary:
                    scores[c] += self.conditionals[c][word]
            
        return scores, max(scores, key=scores.get)

# %%
train_path = "./newsgroups/20news-bydate-train/"
test_path = "./newsgroups/20news-bydate-test/"

# %%
clf = NaiveBayesClassifier()
clf.train_py(train_path)
# Out:
# alt.atheism
# comp.graphics
# comp.os.ms-windows.misc
# comp.sys.ibm.pc.hardware
# comp.sys.mac.hardware
# comp.windows.x
# misc.forsale
# rec.autos
# rec.motorcycles
# rec.sport.baseball
# rec.sport.hockey
# sci.crypt
# sci.electronics
# sci.med
# sci.space
# soc.religion.christian
# talk.politics.guns
# talk.politics.mideast
# talk.politics.misc
# talk.religion.misc

# %% [markdown]
# #### NaiveBayesClassifier()._buildVocab
#
# The _buildVocab()_ method of NaiveBayesClassifier reads through all training documents and extracts all the relevant word counts.
#
# You can access the term frequencies of all classes as shown below.

# %%
clf.num_docs # number of all documents
clf.vocabulary # dictionary of term:count
clf.classes['rec.autos']['doc_counts'] # number of documents in class rec.autos
clf.classes['rec.autos']['term_counts'] # number of words in class rec.autos
clf.classes['rec.autos']['terms'] # dictionary of term:count of class rec.autos
# Out:
# {'in': 2076,
#  'article': 440,
#  'c4vir5': 2,
#  'l3r': 2,
#  'shuksan': 4,
#  'ds': 4,
#  'boeing': 22,
#  'com': 540,
#  'fredd': 2,
#  'fred': 12,
#  'dickey': 2,
#  'writes': 484,
#  'carolinafan': 3,
#  'uiuc': 68,
#  'cka52397': 14,
#  'uxa': 17,
#  'cso': 38,
#  'edu': 557,
#  'wrote': 25,
#  'have': 915,
#  'been': 208,
#  'active': 5,
#  'defending': 4,
#  'saturn': 72,
#  'lately': 1,
#  'on': 1059,
#  'the': 5999,
#  'net': 25,
#  'and': 2285,
#  'would': 435,
#  'like': 326,
#  'to': 2621,
#  'state': 67,
#  'my': 708,
#  'full': 34,
#  'opinion': 15,
#  'subject': 31,
#  'rather': 42,
#  'than': 273,
#  'just': 335,
#  'reply': 16,
#  'others': 37,
#  'points': 11,
#  'biggest': 8,
#  'problem': 105,
#  'some': 271,
#  'people': 173,
#  'seem': 33,
#  'be': 705,
#  'having': 29,
#  'is': 1599,
#  'that': 1446,
#  'dealers': 27,
#  'make': 134,
#  '2k': 12,
#  'car': 833,
#  'think': 212,
#  'most': 127,
#  'will': 329,
#  'agree': 34,
#  'with': 718,
#  'me': 384,
#  'comparably': 2,
#  'priced': 10,
#  'its': 111,
#  'competitors': 5,
#  'they': 692,
#  'aren': 43,
#  'overpriced': 5,
#  'compared': 10,
#  'cars': 364,
#  'their': 190,
#  'class': 16,
#  'don': 305,
#  'understand': 26,
#  'point': 78,
#  'of': 2077,
#  'arguing': 2,
#  'over': 125,
#  'whether': 31,
#  'dealer': 133,
#  'makes': 42,
#  'or': 640,
#  'not': 694,
#  'never': 108,
#  'understood': 4,
#  'what': 346,
#  'big': 66,
#  'deal': 54,
#  'profits': 6,
#  'either': 63,
#  'only': 199,
#  'thing': 96,
#  'can': 490,
#  'figure': 22,
#  'out': 407,
#  'believe': 52,
#  'if': 608,
#  'minimize': 5,
#  'profit': 35,
#  'total': 11,
#  'pocket': 19,
#  'expenses': 5,
#  'for': 1141,
#  'while': 101,
#  'this': 739,
#  'may': 170,
#  'true': 45,
#  'cases': 14,
#  'do': 371,
#  'it': 1627,
#  'generally': 20,
#  'bought': 69,
#  'sl': 6,
#  'january': 3,
#  '92': 27,
#  'at': 562,
#  'time': 160,
#  'based': 42,
#  'studying': 2,
#  'prices': 24,
#  'decided': 26,
#  'there': 402,
#  'was': 586,
#  'no': 274,
#  'comparable': 7,
#  'as': 475,
#  'cheaply': 3,
#  'sure': 90,
#  'maybe': 47,
#  'could': 151,
#  'talked': 8,
#  'price': 121,
#  'other': 187,
#  'but': 660,
#  'wouldn': 38,
#  'any': 374,
#  'different': 67,
#  'important': 36,
#  'how': 211,
#  'much': 213,
#  'money': 58,
#  'left': 84,
#  'after': 124,
#  'buy': 101,
#  'reducing': 6,
#  'same': 132,
#  'saving': 8,
#  'show': 24,
#  'saves': 5,
#  'll': 78,
#  'experience': 51,
#  'has': 350,
#  'does': 150,
#  'necessarily': 16,
#  'save': 14,
#  'say': 99,
#  'you': 1359,
#  'your': 380,
#  '13k': 7,
#  '1000': 17,
#  'then': 147,
#  'paying': 18,
#  '12k': 6,
#  'so': 364,
#  'isn': 43,
#  'moreover': 3,
#  'really': 149,
#  'reduce': 9,
#  'margin': 5,
#  'by': 300,
#  'even': 127,
#  'better': 121,
#  'deals': 4,
#  'already': 31,
#  'below': 25,
#  'market': 51,
#  'average': 19,
#  '2000': 12,
#  'attract': 3,
#  'more': 284,
#  'saturns': 8,
#  'because': 149,
#  'them': 212,
#  'force': 18,
#  'lower': 26,
#  'survive': 7,
#  'now': 111,
#  'owners': 35,
#  'benefit': 6,
#  'from': 345,
#  'buyers': 5,
#  'pay': 58,
#  'less': 62,
#  '02': 11,
#  'doug': 11,
#  '1993apr5': 15,
#  '135153': 1,
#  '11132': 1,
#  'wdl': 1,
#  'loral': 7,
#  'gwm': 4,
#  'spl1': 4,
#  'spl': 4,
#  'gary': 6,
#  'mahan': 4,
#  'road': 106,
#  'track': 25,
#  '88': 10,
#  'bmw325is': 1,
#  '60': 38,
#  '5s': 1,
#  'mile': 23,
#  '15': 20,
#  '7s': 1,
#  'test': 44,
#  'annual': 6,
#  '1993': 35,
#  '3s': 1,
#  '16': 24,
#  '2s': 1,
#  'those': 111,
#  'are': 829,
#  'numbers': 35,
#  'quoting': 3,
#  'driven': 45,
#  'older': 20,
#  'model': 70,
#  'newer': 17,
#  'sounds': 36,
#  'got': 100,
#  'ringer': 2,
#  '325is': 6,
#  'drove': 30,
#  'definitely': 13,
#  'faster': 22,
#  'want': 127,
#  'quote': 10,
#  'aw': 2,
#  'autofile': 2,
#  'shows': 14,
#  'quotes': 3,
#  'driver': 83,
#  'figures': 17,
#  'oh': 28,
#  'btw': 22,
#  'these': 169,
#  '325i': 4,
#  'know': 199,
#  'addition': 16,
#  'variable': 3,
#  'valve': 29,
#  'timing': 13,
#  'affects': 2,
#  'take': 113,
#  'word': 12,
#  'go': 140,
#  'drive': 135,
#  'teddy': 9,
#  'thanks': 99,
#  'all': 403,
#  'who': 180,
#  'responded': 5,
#  'posting': 33,
#  'truck': 42,
#  'headlights': 15,
#  'low': 56,
#  'beam': 4,
#  'loose': 6,
#  'wire': 4,
#  'connection': 2,
#  'fuse': 3,
#  'minority': 1,
#  'suggested': 9,
#  'again': 56,
#  'says': 48,
#  '1984': 9,
#  'chev': 1,
#  's10': 2,
#  'pickup': 15,
#  'turn': 59,
#  'signal': 19,
#  'stop': 38,
#  'turning': 8,
#  'cause': 32,
#  'automaticaly': 1,
#  'mechanical': 19,
#  'steering': 31,
#  'wheel': 68,
#  'note': 31,
#  'an': 433,
#  'gt': 43,
#  'grant': 1,
#  'installed': 30,
#  'wolfson': 2,
#  'regatta': 1,
#  'sps': 13,
#  'mot': 28,
#  'stephen': 9,
#  '1993mar31': 2,
#  '193406': 1,
#  '29625': 1,
#  'ugle': 1,
#  'unit': 28,
#  'oep': 2,
#  'colargol': 1,
#  'edb': 1,
#  'tih': 1,
#  'which': 215,
#  'turns': 8,
#  'into': 125,
#  'teenagers': 21,
#  'when': 283,
#  'gets': 31,
#  'old': 70,
#  'lifelength': 1,
#  'volvo': 25,
#  'norway': 4,
#  '18': 6,
#  'years': 100,
#  'sweden': 13,
#  '20': 37,
#  'course': 58,
#  'someone': 91,
#  'pointed': 7,
#  'saab': 21,
#  'running': 29,
#  'least': 43,
#  '10': 66,
#  'ads': 7,
#  'milage': 6,
#  'significantly': 11,
#  'us': 149,
#  'every': 77,
#  've': 134,
#  'ever': 70,
#  'owned': 11,
#  'lasted': 1,
#  'far': 41,
#  'longer': 15,
#  '1981': 9,
#  '245': 1,
#  '125': 4,
#  '000': 59,
#  'miles': 86,
#  'still': 104,
#  '1983': 9,
#  '242': 1,
#  '195': 9,
#  '244': 2,
#  '175': 3,
#  'admit': 9,
#  'repair': 19,
#  'cost': 51,
#  'high': 88,
#  'aptitude': 1,
#  'own': 74,
#  'finding': 8,
#  'good': 262,
#  'indi': 1,
#  'mechanic': 18,
#  'avoid': 24,
#  'breakdowns': 1,
#  'rest': 22,
#  'cheap': 13,
#  'sum': 1,
#  'repairs': 15,
#  'mufflers': 2,
#  'radiator': 14,
#  'whoa': 1,
#  'bad': 60,
#  'record': 20,
#  'fairly': 20,
#  'hard': 50,
#  'none': 11,
#  'head': 35,
#  'line': 42,
#  'going': 97,
#  '30': 38,
#  'mph': 40,
#  'first': 87,
#  'two': 115,
#  'spend': 25,
#  'lot': 88,
#  'operating': 9,
#  'life': 52,
#  'speedometer': 4,
#  'pegged': 2,
#  'reason': 51,
#  '84': 9,
#  'doesn': 71,
#  '120': 9,
#  'speedo': 3,
#  'hate': 15,
#  'volvos': 11,
#  'traumatized': 2,
#  '745': 2,
#  'turbo': 45,
#  'wagon': 46,
#  'blowing': 5,
#  'away': 58,
#  'mihir': 5,
#  'pramod': 1,
#  'shah': 5,
#  'mps1': 2,
#  'cec1': 2,
#  'wustl': 3,
#  'robert': 18,
#  'wade': 9,
#  'until': 32,
#  'retailers': 1,
#  'built': 22,
#  'city': 18,
#  'medium': 1,
#  'large': 19,
#  'cities': 5,
#  'small': 62,
#  'handful': 2,
#  'sacramento': 3,
#  'dealerships': 2,
#  'ralph': 2,
#  'bean': 3,
#  'hprnd': 1,
#  'rose': 5,
#  'hp': 62,
#  'looking': 87,
#  'replacement': 13,
#  'radio': 20,
#  'tape': 3,
#  'player': 3,
#  'toyota': 63,
#  'tercel': 12,
#  'standard': 28,
#  'off': 161,
#  'shelf': 2,
#  'fine': 40,
#  'place': 39,
#  'gone': 12,
#  'service': 32,
#  'merchandise': 3,
#  'etc': 77,
#  'application': 6,
#  'book': 11,
#  'slide': 3,
#  'new': 192,
#  'minimal': 3,
#  'spent': 4,
#  'hooking': 1,
#  'up': 299,
#  'adjusting': 2,
#  'dashboard': 1,
#  'put': 85,
#  'similar': 22,
#  'hear': 34,
#  'brand': 8,
#  'easy': 31,
#  'change': 70,
#  'relevant': 1,
#  'information': 46,
#  'please': 91,
#  'answer': 20,
#  'via': 6,
#  'mail': 64,
#  'tom': 23,
#  'ostrand': 2,
#  'tjo': 1,
#  'scr': 1,
#  'siemens': 2,
#  'corporate': 7,
#  'research': 16,
#  'phone': 24,
#  '609': 2,
#  '734': 2,
#  '6569': 1,
#  '755': 1,
#  'college': 6,
#  'east': 9,
#  'fax': 19,
#  '6565': 1,
#  'princeton': 2,
#  'nj': 26,
#  '08540': 1,
#  '6668': 1,
#  'am': 143,
#  'thinking': 29,
#  'about': 455,
#  'getting': 64,
#  'infiniti': 5,
#  'g20': 5,
#  'consumer': 25,
#  'reports': 17,
#  'ranked': 1,
#  'many': 98,
#  'catagories': 1,
#  'including': 11,
#  'highest': 2,
#  'reliability': 25,
#  'index': 3,
#  'compact': 5,
#  'mitsubushi': 1,
#  'galant': 4,
#  'second': 30,
#  'followed': 2,
#  'honda': 68,
#  'accord': 24,
#  'couple': 29,
#  'things': 77,
#  'though': 69,
#  'around': 102,
#  'yet': 28,
#  'see': 130,
#  'anyone': 139,
#  'driving': 108,
#  'lots': 21,
#  'special': 13,
#  'where': 131,
#  'get': 285,
#  'infinity': 4,
#  'fully': 15,
#  'loaded': 14,
#  'check': 57,
#  'match': 13,
#  'doing': 54,
#  'releasing': 3,
#  'update': 2,
#  'mid': 24,
#  'version': 18,
#  'includes': 8,
#  'dual': 4,
#  'air': 51,
#  'bags': 3,
#  'rid': 5,
#  'guess': 40,
#  'question': 63,
#  'also': 199,
#  'give': 47,
#  'feedback': 10,
#  'carl': 2,
#  'hoffman': 2,
#  'mitsubishi': 8,
#  'camary': 1,
#  '175719': 1,
#  '7892': 1,
#  'telxon': 10,
#  'mis': 10,
#  'joes': 4,
#  'joe': 9,
#  'staudt': 4,
#  '1piip4': 1,
#  'bo6': 1,
#  'agate': 3,
#  'berkeley': 9,
#  'hubertc': 1,
#  'whistle': 1,
#  'cs': 48,
#  'hung': 2,
#  'hsien': 1,
#  'hubert': 1,
#  'chang': 1,
#  'hi': 23,
#  'being': 52,
#  'owner': 48,
#  'pretty': 49,
#  'basics': 2,
#  'maintaining': 3,
#  'following': 21,
#  'oil': 131,
#  'changed': 23,
#  '3000': 15,
#  'filter': 10,
#  'too': 137,
#  'tires': 78,
#  'before': 79,
#  'way': 120,
#  'fill': 5,
#  'tank': 14,
#  'monthly': 7,
#  'often': 35,
#  'one': 338,
#  'slow': 25,
#  'leak': 10,
#  'tire': 45,
#  'should': 173,
#  'fix': 19,
#  'thank': 15,
#  'fluids': 25,
#  'regularly': 8,
#  'month': 27,
#  'gas': 56,
#  'work': 97,
#  'well': 143,
#  'engine': 199,
#  'hot': 19,
#  'accurate': 5,
#  'cool': 13,
#  'station': 15,
#  'craig': 46,
#  '212645': 1,
#  '15988': 1,
#  'nntpd': 1,
#  'lkg': 1,
#  'dec': 13,
#  'kenyon': 2,
#  'xqzmoi': 1,
#  'enet': 6,
#  'stardog': 1,
#  'champion': 3,
#  'great': 66,
#  'handle': 25,
#  'corner': 16,
#  'accelerate': 7,
#  'integra': 38,
#  'ask': 43,
#  'yourself': 20,
#  'moonroof': 7,
#  'sliding': 7,
#  'sunshade': 2,
#  'wimpy': 2,
#  'pop': 5,
#  'sunroofs': 3,
#  'power': 91,
#  'roofs': 12,
#  'opaque': 2,
#  'opened': 3,
#  'closed': 3,
#  'let': 56,
#  'light': 56,
#  'shaded': 2,
#  'nothing': 32,
#  'comes': 20,
#  '93': 35,
#  'gs': 14,
#  'hahaha': 1,
#  'sentiments': 1,
#  'exactly': 25,
#  '3mwf2b1w165w': 2,
#  'njcc': 4,
#  'wisdom': 5,
#  'bubble': 4,
#  'org': 47,
#  'jonc': 2,
#  'cochran': 2,
#  'add': 34,
#  'beretta': 20,
#  'gtz': 15,
#  'kick': 3,
#  'butt': 4,
#  'anyday': 2,
#  'cheaper': 15,
#  'boot': 7,
#  'definate': 1,
#  'grain': 1,
#  'salt': 1,
#  'performance': 62,
#  'data': 19,
#  'poster': 4,
#  'proof': 9,
#  'friend': 40,
#  'blew': 2,
#  'last': 86,
#  'week': 17,
#  'here': 143,
#  'acceleration': 22,
#  'handling': 23,
#  'motor': 30,
#  'trend': 7,
#  'apr': 5,
#  '87': 14,
#  'acc': 4,
#  '86': 16,
#  'slalom': 5,
#  '63': 2,
#  '68': 3,
#  'wrong': 50,
#  'why': 147,
#  'look': 76,
#  'times': 54,
#  '67': 4,
#  'right': 148,
#  'along': 22,
#  '14': 26,
#  'inch': 9,
#  'weather': 17,
#  'xgtv4': 3,
#  'mention': 19,
#  'rides': 7,
#  'alot': 14,
#  'acceleartion': 2,
#  'vary': 14,
#  'magazine': 27,
#  'quarter': 2,
#  'tell': 39,
#  'furthermore': 3,
#  'definately': 3,
#  'outrun': 1,
#  'end': 49,
#  '136': 1,
#  '141': 5,
#  'fast': 57,
#  'certainly': 28,
#  'keep': 54,
#  'probably': 68,
#  'higher': 28,
#  'top': 49,
#  'speed': 140,
#  'due': 21,
#  'horsepower': 9,
#  'advantage': 14,
#  '160': 4,
#  '117': 6,
#  'torque': 34,
#  'vs': 14,
#  '180': 3,
#  'always': 46,
#  'exact': 12,
#  'self': 14,
#  'torqye': 2,
#  'gearing': 6,
#  '8000': 7,
#  'rpm': 6,
#  'difference': 30,
#  'call': 33,
#  'moster': 2,
#  'costs': 32,
#  '19': 3,
#  '111': 1,
#  'tested': 6,
#  '134': 1,
#  'nicities': 1,
#  'airbag': 12,
#  'antilock': 1,
#  'brakes': 49,
#  'available': 33,
#  'models': 62,
#  'abs': 42,
#  'considering': 20,
#  'almost': 32,
#  'dollars': 10,
#  'quad4': 7,
#  'reliable': 19,
#  'sense': 14,
#  'coupe': 13,
#  'trying': 34,
#  'quad': 11,
#  'yeah': 28,
#  'definition': 4,
#  'safe': 21,
#  'engines': 22,
#  'general': 26,
#  'near': 26,
#  'perfect': 7,
#  'hell': 38,
#  'smoother': 8,
#  'quieter': 3,
#  'balance': 7,
#  'shafts': 9,
#  'acura': 12,
#  'wins': 2,
#  'reliablity': 2,
#  'contest': 2,
#  'hands': 16,
#  'down': 104,
#  'rev': 11,
#  'day': 60,
#  'everyday': 4,
#  'blow': 11,
#  'hose': 10,
#  'crack': 2,
#  'block': 17,
#  'anything': 67,
#  'else': 51,
#  'speak': 10,
#  'expierence': 2,
#  'saying': 20,
#  'highlight': 2,
#  'comparing': 13,
#  'investment': 2,
#  'since': 81,
#  'hold': 12,
#  'value': 31,
#  'considerably': 1,
#  'nice': 52,
#  'job': 35,
#  'sporty': 11,
#  'practical': 2,
#  'flame': 13,
#  'gm': 38,
#  'products': 7,
#  'berreta': 1,
#  'puts': 2,
#  'respectable': 2,
#  'very': 185,
#  'reasonable': 14,
#  'start': 30,
#  'source': 5,
#  'read': 54,
#  'sources': 4,
#  'both': 69,
#  'haven': 32,
#  'gts': 2,
#  'grand': 19,
#  'ams': 1,
#  'similair': 2,
#  'list': 69,
#  'said': 76,
#  'hopefully': 9,
#  'repeating': 1,
#  'horizontally': 1,
#  'mounted': 20,
#  'filters': 1,
#  'ford': 96,
#  'matter': 13,
#  'try': 48,
#  'spill': 3,
#  'half': 16,
#  'quart': 2,
#  'bottom': 16,
#  'st': 7,
#  'lucas': 2,
#  'stlucas': 1,
#  'gdwest': 1,
#  'gd': 1,
#  'disclaimers': 3,
#  'apply': 7,
#  'dynamics': 2,
#  'space': 11,
#  'systems': 30,
#  'san': 14,
#  'diego': 8,
#  'something': 84,
#  'busy': 2,
#  'between': 60,
#  'ultimate': 3,
#  'frisbee': 1,
#  'games': 1,
#  '1993apr3': 2,
#  '005245': 2,
#  '10615': 2,
#  'michael': 15,
#  'apple': 5,
#  'ems': 3,
#  'smith': 24,
#  'peculiar': 4,
#  'tools': 7,
#  'remove': 15,
#  'rear': 67,
#  'springs': 5,
#  'f350': 2,
#  'naah': 1,
#  'coupla': 1,
#  'bumps': 3,
#  '1pq29p': 2,
#  '29p': 2,
#  'seven': 2,
#  'sun': 17,
#  'jfox': 2,
#  'hooksett': 2,
#  'limited': 26,
#  'mentioned': 25,
#  'suv': 11,
#  'spectrum': 3,
#  'range': 26,
#  'explorer': 11,
#  'trooper': 3,
#  'blazer': 6,
#  'montero': 3,
#  'budget': 12,
#  'allows': 10,
#  'land': 21,
#  'cruiser': 11,
#  'advice': 20,
#  'local': 37,
#  'year': 125,
#  'waiting': 12,
#  'forget': 38,
#  'kicking': 3,
#  'rare': 17,
#  'doubt': 14,
#  'parts': 55,
#  'inventory': 2,
#  'hand': 71,
#  'jonathan': 6,
#  'edwards': 9,
#  'intranet': 6,
#  'inc': 14,
#  '617': 5,
#  '527': 3,
#  '7020': 3,
#  '181056': 2,
#  '29411': 2,
#  'mks': 10,
#  'mike': 19,
#  'brookbank': 4,
#  'sister': 5,
#  'mgb': 13,
#  'she': 59,
#  'were': 208,
#  'produced': 9,
#  '1978': 4,
#  '1979': 4,
#  'shape': 13,
#  'bugging': 3,
#  'her': 34,
#  '1980': 2,
#  'selling': 30,
#  'sell': 33,
#  'worthless': 4,
#  'maintains': 3,
#  'actually': 55,
#  'increasing': 4,
#  'result': 16,
#  'availability': 7,
#  'affectionados': 3,
#  'willing': 15,
#  '6k': 5,
#  '8k': 4,
#  'mg': 8,
#  'yes': 37,
#  'mgbs': 1,
#  'earlier': 12,
#  'pre': 7,
#  '74': 8,
#  'usually': 35,
#  'desirable': 3,
#  'certain': 11,
#  'went': 57,
#  'chrome': 4,
#  'bumpers': 6,
#  'ride': 14,
#  'height': 7,
#  'appreciating': 1,
#  'slowly': 3,
#  'ones': 28,
#  'stable': 4,
#  'level': 13,
#  'moment': 1,
#  'require': 11,
#  'extremely': 11,
#  'condition': 17,
#  'regular': 21,
#  'maintenance': 18,
#  'kept': 8,
#  'long': 81,
#  'plenty': 16,
#  'ouththere': 1,
#  'fun': 34,
#  'little': 94,
#  'keeping': 8,
#  'solely': 1,
#  'hopes': 1,
#  'appreciate': 14,
#  'worth': 32,
#  'real': 59,
#  'profitable': 1,
#  'rick': 3,
#  'guynn': 1,
#  'soontobe': 1,
#  'mga': 1,
#  '1600': 5,
#  'mkii': 1,
#  'rcg1597': 1,
#  'zeus': 2,
#  'tamu': 9,
#  'rebuild': 10,
#  'complete': 11,
#  'finished': 1,
#  'texas': 33,
#  'university': 53,
#  'keeper': 3,
#  'eternal': 9,
#  'octagon': 1,
#  '69': 4,
#  'roadster': 1,
#  'marque': 1,
#  'symbol': 1,
#  'registered': 2,
#  'soon': 14,
#  'refuses': 1,
#  'die': 7,
#  'honest': 11,
#  'past': 20,
#  'winter': 10,
#  'nyc': 1,
#  'killington': 1,
#  'vt': 2,
#  '1990': 12,
#  'convertible': 37,
#  'talk': 12,
#  'poor': 9,
#  'reputation': 1,
#  'snow': 21,
#  'excellent': 20,
#  'set': 31,
#  'noika': 2,
#  'nr10s': 1,
#  'footed': 1,
#  'severe': 8,
#  'conditions': 15,
#  'plowed': 1,
#  'through': 71,
#  ...}

# %%
ty, py = clf.test(test_path)
# Out:
# alt.atheism
# comp.graphics
# comp.os.ms-windows.misc
# comp.sys.ibm.pc.hardware
# comp.sys.mac.hardware
# comp.windows.x
# misc.forsale
# rec.autos
# rec.motorcycles
# rec.sport.baseball
# rec.sport.hockey
# sci.crypt
# sci.electronics
# sci.med
# sci.space
# soc.religion.christian
# talk.politics.guns
# talk.politics.mideast
# talk.politics.misc
# talk.religion.misc

# %%
print('Accuracy: %2.2f %%' % (100. * metrics.accuracy_score(ty, py)))
# Out:
# Accuracy: 75.73 %

# %% [markdown]
# ### Plot confusion matrix

# %%
import itertools

#
# Code from https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
#

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Compute confusion matrix
cnf_matrix = metrics.confusion_matrix(ty, py)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=clf.classes.keys(), title='Confusion matrix, without normalization')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## Comparison to Sklearn's Implementation

# %%
from sklearn.datasets import load_files
from sklearn import feature_extraction
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB

twenty_train = load_files('./newsgroups/20news-bydate-train/', encoding='latin1')
twenty_test = load_files('./newsgroups/20news-bydate-test/', encoding='latin1')

# %%
vectorizer = feature_extraction.text.CountVectorizer()#(max_features=len(clf.vocabulary))
train_X, train_y = vectorizer.fit_transform(twenty_train.data), twenty_train.target
test_X, test_y = vectorizer.transform(twenty_test.data), twenty_test.target
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (11314, 130107) (11314,) (7532, 130107) (7532,)

# %%
clf = MultinomialNB()
clf.fit(train_X, train_y)
pred_y = clf.predict(test_X)

print('Accuracy: %2.2f %%' % (100. * metrics.accuracy_score(test_y, pred_y)))
# Out:
# Accuracy: 77.28 %

# %%
# Compute confusion matrix
cnf_matrix = metrics.confusion_matrix(test_y, pred_y)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=twenty_test.target_names, title='Confusion matrix, without normalization')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ### Appendix: Can we do better?

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV


clf = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', MultinomialNB()),
               ])

parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'clf__alpha': (1.0, 0.1),
             }

gs_clf = GridSearchCV(clf, parameters, n_jobs=-1)
gs_clf.fit(twenty_train.data, twenty_train.target)
pred = gs_clf.predict(twenty_test.data)

print('Accuracy: %2.2f %%' % (100. * metrics.accuracy_score(twenty_test.target, pred)))

for param_name in sorted(parameters.keys()):
    print(param_name,":", gs_clf.best_params_[param_name])
# Out:
# Accuracy: 81.78 %
# clf__alpha : 0.1
# tfidf__use_idf : True
# vect__ngram_range : (1, 2)

# %%
# Compute confusion matrix
cnf_matrix = metrics.confusion_matrix(twenty_test.target, pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=twenty_test.target_names, title='Confusion matrix, without normalization')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# further details can be found at http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
